# %%
import requests
import pandas as pd
import json
import numpy as np


# Setup pitch and plot
from mplsoccer.pitch import Pitch ,VerticalPitch

username = "XXX"
password = "XXX"


from skillcorner.client import SkillcornerClient
client=SkillcornerClient(username=username,password=password)

def time_to_seconds(time_str):
    if time_str is None:
        return 90 * 60  # 120 minutes = 7200 seconds
    h, m, s = map(int, time_str.split(':'))
    return h * 3600 + m * 60 + s

# %% [markdown]
# # 1.0 Extract the tracking data

# %%
####-----------------------------------------------------------------------------------
# If you're a skillcorner client and you know your match_id you can use the pyton client
###------------------------------------------------------------------------------------
# match_id=1886347
# client.save_match_tracking_data(match_id,
#                                 params={'data_version':3},
#                                 filepath=f'{match_id}_tracking_raw.jsonl')

####-----------------------------------------------------------------------------------
# If you've cloned the repo and are in your local machine
###------------------------------------------------------------------------------------
# match_id=1886347
# raw_data=pd.read_json(f'../data/matches/{match_id}/{match_id}_tracking_extrapolated.jsonl', lines=True)

####-----------------------------------------------------------------------------------
# If you're on a separate project/environemnt
###------------------------------------------------------------------------------------
match_id=1886347
# Construct the raw GitHub URL
tracking_data_github_url=f'https://media.githubusercontent.com/media/SkillCorner/opendata/741bdb798b0c1835057e3fa77244c1571a00e4aa/data/matches/{match_id}/{match_id}_tracking_extrapolated.jsonl' # Data is stored using GitLFS
raw_data=pd.read_json(tracking_data_github_url,lines=True)


# This is common
raw_df=pd.json_normalize(raw_data.to_dict('records'), 'player_data',
                         ['frame','timestamp','period','possession','ball_data'])

# Extract 'player_id' and 'group from the 'possession' dictionary
raw_df['possession_player_id'] = raw_df['possession'].apply(lambda x: x.get('player_id'))
raw_df['possession_group'] = raw_df['possession'].apply(lambda x: x.get('group'))



# (Optional) Expand the ball_data with json_normalize
raw_df[['ball_x','ball_y','ball_z','is_detected_ball']]=pd.json_normalize(raw_df.ball_data)


# (Optional) Drop the original 'possession' column if you no longer need it
raw_df = raw_df.drop(columns=['possession','ball_data'])

# Add the match_id identifier to your dataframe
raw_df['match_id']=match_id
tracking_df=raw_df.copy()
tracking_df.head()
# Out:
# https://media.githubusercontent.com/media/SkillCorner/opendata/741bdb798b0c1835057e3fa77244c1571a00e4aa/data/matches/1886347/1886347_tracking_extrapolated.jsonl
#        x      y  player_id  is_detected frame  timestamp period  \
# 0 -39.63  -0.08      51009        False    10 2025-10-07    1.0
# 1 -19.21  -9.18     176224         True    10 2025-10-07    1.0
# 2 -21.83   0.47      51649         True    10 2025-10-07    1.0
# 3  -1.16 -32.47      50983         True    10 2025-10-07    1.0
# 4 -18.88  15.73     735578         True    10 2025-10-07    1.0
#
#    possession_player_id possession_group  ball_x  ball_y  ball_z  \
# 0                   NaN             None    0.32    0.38    0.13
# 1                   NaN             None    0.32    0.38    0.13
# 2                   NaN             None    0.32    0.38    0.13
# 3                   NaN             None    0.32    0.38    0.13
# 4                   NaN             None    0.32    0.38    0.13
#
#    is_detected_ball  match_id
# 0              True   1886347
# 1              True   1886347
# 2              True   1886347
# 3              True   1886347
# 4              True   1886347

# %% [markdown]
# # Congrats ! You have your (maybe) first tracking data frame

# %% [markdown]
# Now we need to get player information !

# %% [markdown]
# # 2.0 Extract meta data from matches

# %%
####-----------------------------------------------------------------------------------
# If you're a skillcorner client and you know your match_id you can use the python client
###------------------------------------------------------------------------------------
# match_id=1886347
# raw_match_data=client.get_match(match_id)


####-----------------------------------------------------------------------------------
# If you've cloned the repo and are in your local machine
###------------------------------------------------------------------------------------
# match_id = 1886347
# file_path = f'../data/matches/{match_id}/{match_id}_match.json'

# with open(file_path, 'r') as f:
#     raw_match_data = json.load(f)


####-----------------------------------------------------------------------------------
# If you're on a separate project/environment
###------------------------------------------------------------------------------------
match_id=1886347
meta_data_github_url=f'https://raw.githubusercontent.com/SkillCorner/opendata/741bdb798b0c1835057e3fa77244c1571a00e4aa/data/matches/{match_id}/{match_id}_match.json'
# Read the JSON data as a JSON object
response = requests.get(meta_data_github_url)
raw_match_data = response.json()


# The output has nested json elements. We process them
raw_match_df=pd.json_normalize(raw_match_data,max_level=2)
raw_match_df['home_team_side']=raw_match_df['home_team_side'].astype(str)

players_df = pd.json_normalize(
    raw_match_df.to_dict('records'),
    record_path='players',
    meta=['home_team_score', 'away_team_score', 'date_time',
          'home_team_side',
         'home_team.name','home_team.id',
         'away_team.name','away_team.id'
         ], # data we keep
)


# Take only players who played and create their total time
players_df=players_df[~((players_df.start_time.isna())&(players_df.end_time.isna()))]
players_df['total_time']=players_df['end_time'].apply(time_to_seconds)-players_df['start_time'].apply(time_to_seconds)

# Create a flag for GK
players_df['is_gk']=players_df['player_role.acronym']=='GK'

# Add a flag if the given player is home or away
players_df['match_name']=players_df['home_team.name']+' vs '+players_df['away_team.name']


# Add a flag if the given player is home or away
players_df['home_away_player']=np.where(players_df.team_id==players_df['home_team.id'],'Home','Away')

# Create flag from player
players_df['team_name']=np.where(players_df.team_id==players_df['home_team.id'],players_df['home_team.name'],players_df['away_team.name'])

# Figure out sides
players_df[['home_team_side_1st_half','home_team_side_2nd_half']]=players_df['home_team_side'].astype(str).str.strip('[]').str.replace("'",'').str.split(', ', expand=True)
# Clean up sides
players_df['direction_player_1st_half']=np.where(players_df.home_away_player=='Home',players_df.home_team_side_1st_half,players_df.home_team_side_2nd_half)
players_df['direction_player_2nd_half']=np.where(players_df.home_away_player=='Home',players_df.home_team_side_2nd_half,players_df.home_team_side_1st_half)



#Clean up and keep the columns that we want to keep about

columns_to_keep=['start_time','end_time','match_name','date_time','home_team.name','away_team.name',
                'id','short_name','number','team_id','team_name','player_role.position_group','total_time',
                 'player_role.name','player_role.acronym','is_gk',
                'direction_player_1st_half','direction_player_2nd_half']
players_df=players_df[columns_to_keep]
players_df.head()
# Out:
#   start_time  end_time                               match_name  \
# 0   00:00:00  01:25:21  Auckland FC vs Newcastle United Jets FC
# 1   00:00:00      None  Auckland FC vs Newcastle United Jets FC
# 2   00:00:00  01:16:37  Auckland FC vs Newcastle United Jets FC
# 3   00:00:00  01:24:58  Auckland FC vs Newcastle United Jets FC
# 4   00:00:00      None  Auckland FC vs Newcastle United Jets FC
#
#               date_time home_team.name            away_team.name      id  \
# 0  2024-11-30T04:00:00Z    Auckland FC  Newcastle United Jets FC   38673
# 1  2024-11-30T04:00:00Z    Auckland FC  Newcastle United Jets FC   51713
# 2  2024-11-30T04:00:00Z    Auckland FC  Newcastle United Jets FC   50951
# 3  2024-11-30T04:00:00Z    Auckland FC  Newcastle United Jets FC   50978
# 4  2024-11-30T04:00:00Z    Auckland FC  Newcastle United Jets FC  133498
#
#     short_name  number  team_id                 team_name  \
# 0       G. May      10     4177               Auckland FC
# 1   C. Elliott      17     4177               Auckland FC
# 2   J. Brimmer      22     4177               Auckland FC
# 3   C. Timmins      19     1805  Newcastle United Jets FC
# 4  F. De Vries      15     4177               Auckland FC
#
#   player_role.position_group  total_time         player_role.name  \
# 0             Center Forward        5121           Center Forward
# 1                  Full Back        5400               Right Back
# 2             Center Forward        4597           Center Forward
# 3                   Midfield        5098  Left Defensive Midfield
# 4                  Full Back        5400                Left Back
#
#   player_role.acronym  is_gk direction_player_1st_half  \
# 0                  CF  False             right_to_left
# 1                  RB  False             right_to_left
# 2                  CF  False             right_to_left
# 3                 LDM  False             left_to_right
# 4                  LB  False             right_to_left
#
#   direction_player_2nd_half
# 0             left_to_right
# 1             left_to_right
# 2             left_to_right
# 3             right_to_left
# 4             left_to_right

# %% [markdown]
# # We successfully prepared all the meta data we need for our tracking data

# %% [markdown]
# # 3.0 Merge Dataframes

# %%
# Merging datasets
enriched_tracking_data=tracking_df.merge(players_df,
                                    left_on=['player_id'],
                                    right_on=['id'])
enriched_tracking_data.head()
# Out:
#        x      y  player_id  is_detected frame  timestamp period  \
# 0 -39.63  -0.08      51009        False    10 2025-10-07    1.0
# 1 -19.21  -9.18     176224         True    10 2025-10-07    1.0
# 2 -21.83   0.47      51649         True    10 2025-10-07    1.0
# 3  -1.16 -32.47      50983         True    10 2025-10-07    1.0
# 4 -18.88  15.73     735578         True    10 2025-10-07    1.0
#
#    possession_player_id possession_group  ball_x  ...  number  team_id  \
# 0                   NaN             None    0.32  ...       1     1805
# 1                   NaN             None    0.32  ...       4     1805
# 2                   NaN             None    0.32  ...      15     1805
# 3                   NaN             None    0.32  ...      14     1805
# 4                   NaN             None    0.32  ...      33     1805
#
#                   team_name  player_role.position_group total_time  \
# 0  Newcastle United Jets FC                       Other       5400
# 1  Newcastle United Jets FC            Central Defender       5400
# 2  Newcastle United Jets FC            Central Defender       5400
# 3  Newcastle United Jets FC                   Full Back       5400
# 4  Newcastle United Jets FC                   Full Back       5400
#
#     player_role.name player_role.acronym  is_gk direction_player_1st_half  \
# 0         Goalkeeper                  GK   True             left_to_right
# 1  Right Center Back                 RCB  False             left_to_right
# 2   Left Center Back                 LCB  False             left_to_right
# 3         Right Back                  RB  False             left_to_right
# 4          Left Back                  LB  False             left_to_right
#
#   direction_player_2nd_half
# 0             right_to_left
# 1             right_to_left
# 2             right_to_left
# 3             right_to_left
# 4             right_to_left
#
# [5 rows x 32 columns]

# %% [markdown]
# # Now our data is completed

# %% [markdown]
# ---

# %% [markdown]
# # 4.0 Let's see an example of how to visualize average positions, accounting for play direction

# %%
# Filtering for frames with a team in possession
filtered_df=enriched_tracking_data[enriched_tracking_data['possession_group'].notnull()].copy()


# We basically want to convert the X and Y to make sure we're always visualizing left to right. A player's XY will depend on the half so the straight average doesn't work

filtered_df['direction_player'] = np.where(filtered_df['period'] == 1, filtered_df['direction_player_1st_half'], filtered_df['direction_player_2nd_half'])
filtered_df['x'] = np.where(filtered_df['direction_player'] == 'right_to_left', -filtered_df['x'], filtered_df['x']) # Convert X
filtered_df['y'] = np.where(filtered_df['direction_player'] == 'right_to_left', -filtered_df['y'], filtered_df['y']) # Convert Y

# Create some flags in case we need them later
filtered_df['possession_team_name'] = np.where(filtered_df['possession_group'] == 'home team', filtered_df['home_team.name'], filtered_df['away_team.name'])
filtered_df['possession_flag'] = np.where(filtered_df['possession_team_name'] == filtered_df['team_name'], 'IP', 'OOP')


# At this point all of our players have their X and Y adjusted from left to right , so we can aggregate for across the game

aggregated_df = filtered_df.groupby(['player_id',
                                     'possession_group',
                                     'team_name',
                                     'possession_team_name',
                                     'possession_flag',  # This will allow us to check the position of the player when the team is in or out of possession
                                     'start_time', # With this we can filter in or out the players that came on as subs
                                     'number',
                                     'is_gk'])[['x', 'y']].mean().reset_index()

aggregated_df.sort_values(['possession_flag','team_name'])

# We have an aggregate by possession type !
# Out:
#     player_id possession_group                 team_name  \
# 1       14736        home team               Auckland FC
# 3       23418        home team               Auckland FC
# 5       31147        home team               Auckland FC
# 7       33697        home team               Auckland FC
# 9       38673        home team               Auckland FC
# 11      43829        home team               Auckland FC
# 13      50951        home team               Auckland FC
# 23      51667        home team               Auckland FC
# 25      51713        home team               Auckland FC
# 27     133498        home team               Auckland FC
# 29     133501        home team               Auckland FC
# 31     163972        home team               Auckland FC
# 35     285188        home team               Auckland FC
# 55     965685        home team               Auckland FC
# 14      50978        away team  Newcastle United Jets FC
# 16      50983        away team  Newcastle United Jets FC
# 18      51009        away team  Newcastle United Jets FC
# 20      51649        away team  Newcastle United Jets FC
# 32     176224        away team  Newcastle United Jets FC
# 36     560992        away team  Newcastle United Jets FC
# 38     735573        away team  Newcastle United Jets FC
# 40     735574        away team  Newcastle United Jets FC
# 42     735578        away team  Newcastle United Jets FC
# 44     795505        away team  Newcastle United Jets FC
# 46     795506        away team  Newcastle United Jets FC
# 48     795507        away team  Newcastle United Jets FC
# 50     797297        away team  Newcastle United Jets FC
# 52     800320        away team  Newcastle United Jets FC
# 56     966120        away team  Newcastle United Jets FC
# 0       14736        away team               Auckland FC
# 2       23418        away team               Auckland FC
# 4       31147        away team               Auckland FC
# 6       33697        away team               Auckland FC
# 8       38673        away team               Auckland FC
# 10      43829        away team               Auckland FC
# 12      50951        away team               Auckland FC
# 22      51667        away team               Auckland FC
# 24      51713        away team               Auckland FC
# 26     133498        away team               Auckland FC
# 28     133501        away team               Auckland FC
# 30     163972        away team               Auckland FC
# 34     285188        away team               Auckland FC
# 54     965685        away team               Auckland FC
# 15      50978        home team  Newcastle United Jets FC
# 17      50983        home team  Newcastle United Jets FC
# 19      51009        home team  Newcastle United Jets FC
# 21      51649        home team  Newcastle United Jets FC
# 33     176224        home team  Newcastle United Jets FC
# 37     560992        home team  Newcastle United Jets FC
# 39     735573        home team  Newcastle United Jets FC
# 41     735574        home team  Newcastle United Jets FC
# 43     735578        home team  Newcastle United Jets FC
# 45     795505        home team  Newcastle United Jets FC
# 47     795506        home team  Newcastle United Jets FC
# 49     795507        home team  Newcastle United Jets FC
# 51     797297        home team  Newcastle United Jets FC
# 53     800320        home team  Newcastle United Jets FC
# 57     966120        home team  Newcastle United Jets FC
#
#         possession_team_name possession_flag start_time  number  is_gk  \
# 1                Auckland FC              IP   00:00:00       6  False
# 3                Auckland FC              IP   00:00:00      28  False
# 5                Auckland FC              IP   01:25:21       5  False
# 7                Auckland FC              IP   00:00:00       4  False
# 9                Auckland FC              IP   00:00:00      10  False
# 11               Auckland FC              IP   01:09:53      25  False
# 13               Auckland FC              IP   00:00:00      22  False
# 23               Auckland FC              IP   00:00:00      23  False
# 25               Auckland FC              IP   00:00:00      17  False
# 27               Auckland FC              IP   00:00:00      15  False
# 29               Auckland FC              IP   00:00:00      27  False
# 31               Auckland FC              IP   01:16:37       9  False
# 35               Auckland FC              IP   00:00:00      12   True
# 55               Auckland FC              IP   00:00:00      14  False
# 14  Newcastle United Jets FC              IP   00:00:00      19  False
# 16  Newcastle United Jets FC              IP   00:00:00      14  False
# 18  Newcastle United Jets FC              IP   00:00:00       1   True
# 20  Newcastle United Jets FC              IP   00:00:00      15  False
# 32  Newcastle United Jets FC              IP   00:00:00       4  False
# 36  Newcastle United Jets FC              IP   01:00:15      23  False
# 38  Newcastle United Jets FC              IP   00:00:00      39  False
# 40  Newcastle United Jets FC              IP   00:00:00      17  False
# 42  Newcastle United Jets FC              IP   00:00:00      33  False
# 44  Newcastle United Jets FC              IP   00:00:00       7  False
# 46  Newcastle United Jets FC              IP   01:07:43      13  False
# 48  Newcastle United Jets FC              IP   00:00:00      37  False
# 50  Newcastle United Jets FC              IP   01:24:58       6  False
# 52  Newcastle United Jets FC              IP   01:24:58      29  False
# 56  Newcastle United Jets FC              IP   00:00:00      22  False
# 0   Newcastle United Jets FC             OOP   00:00:00       6  False
# 2   Newcastle United Jets FC             OOP   00:00:00      28  False
# 4   Newcastle United Jets FC             OOP   01:25:21       5  False
# 6   Newcastle United Jets FC             OOP   00:00:00       4  False
# 8   Newcastle United Jets FC             OOP   00:00:00      10  False
# 10  Newcastle United Jets FC             OOP   01:09:53      25  False
# 12  Newcastle United Jets FC             OOP   00:00:00      22  False
# 22  Newcastle United Jets FC             OOP   00:00:00      23  False
# 24  Newcastle United Jets FC             OOP   00:00:00      17  False
# 26  Newcastle United Jets FC             OOP   00:00:00      15  False
# 28  Newcastle United Jets FC             OOP   00:00:00      27  False
# 30  Newcastle United Jets FC             OOP   01:16:37       9  False
# 34  Newcastle United Jets FC             OOP   00:00:00      12   True
# 54  Newcastle United Jets FC             OOP   00:00:00      14  False
# 15               Auckland FC             OOP   00:00:00      19  False
# 17               Auckland FC             OOP   00:00:00      14  False
# 19               Auckland FC             OOP   00:00:00       1   True
# 21               Auckland FC             OOP   00:00:00      15  False
# 33               Auckland FC             OOP   00:00:00       4  False
# 37               Auckland FC             OOP   01:00:15      23  False
# 39               Auckland FC             OOP   00:00:00      39  False
# 41               Auckland FC             OOP   00:00:00      17  False
# 43               Auckland FC             OOP   00:00:00      33  False
# 45               Auckland FC             OOP   00:00:00       7  False
# 47               Auckland FC             OOP   01:07:43      13  False
# 49               Auckland FC             OOP   00:00:00      37  False
# 51               Auckland FC             OOP   01:24:58       6  False
# 53               Auckland FC             OOP   01:24:58      29  False
# 57               Auckland FC             OOP   00:00:00      22  False
#
#             x          y
# 1    5.181767  -4.093078
# 3    7.095420   8.334144
# 5   -9.197614   0.121759
# 7   -6.836360   8.199158
# 9   21.607955  -0.350817
# 11  15.965767 -13.335899
# 13  16.022285   3.915758
# 23  -7.584599  -7.521181
# 25   4.349368 -18.779344
# 27   6.148965  21.497048
# 29  17.472935 -15.412136
# 31  22.073179  -5.108414
# 35 -33.228650   0.042024
# 55  16.437281  13.540768
# 14 -10.465071  -0.411385
# 16  -6.232943 -20.825898
# 18 -39.893405  -0.098759
# 20 -19.733565   4.262080
# 32 -19.506128  -9.405119
# 36   2.390597  21.493278
# 38   0.795817  11.138531
# 40  -9.541371  -1.443416
# 42 -16.051153  16.040089
# 44   1.257643  -8.493672
# 46  10.653183   8.017587
# 48   3.855234   5.440460
# 50  -3.379939   3.313851
# 52  15.283728   1.739687
# 56   9.232149  -1.720554
# 0   -2.234893  -4.985066
# 2    1.471689   4.524173
# 4  -16.153102  -0.047837
# 6  -12.365556   4.720194
# 8   17.339157  -2.402899
# 10   5.149852 -12.422452
# 12  11.187824   3.454133
# 22 -12.144375  -6.214512
# 24  -6.745392 -15.178370
# 26  -7.014466  14.449354
# 28   7.520610 -14.147676
# 30   8.389803  -1.188270
# 34 -37.501709  -0.066348
# 54   6.527062  11.827863
# 15 -15.010674  -2.388599
# 17 -19.509945 -14.589830
# 19 -42.900245  -0.261577
# 21 -23.453997   2.641942
# 33 -23.128487  -6.098224
# 37 -13.291888  17.359511
# 39  -8.849593   8.309562
# 41 -14.858964  -2.033530
# 43 -21.537490  12.360332
# 45  -7.885462 -11.744622
# 47  -0.073301   4.214601
# 49  -2.358773   2.186893
# 51 -11.746530   2.681454
# 53   3.322890   4.113916
# 57   0.093383  -3.535352

# %%
# Visualizing the data on a pitch

pitch = Pitch(pitch_type='skillcorner', line_alpha=0.75, pitch_length=105, pitch_width=68,
              pitch_color='#001400', line_color='white', linewidth=1.5)
fig, ax = pitch.grid(figheight=8, endnote_height=0, title_height=0)



# What to visualize
possession = 'IP' # or 'OOP'
team = aggregated_df.team_name.unique().tolist()[1] # Pick one team, you can use the name directly

viz_ip = aggregated_df[(aggregated_df['possession_flag'] == possession) & (aggregated_df['team_name'] == team)].reset_index(drop=True)


ax.scatter(viz_ip['x'], viz_ip['y'],
               c='#32FE6B', alpha=0.95, s=600,
               edgecolors='white', linewidths=2.5, zorder=10,label='team')


# Annotate player numbers
for i, row in viz_ip.iterrows():
    ax.text(row['x'], row['y'], str(row['number']),
            color='black', fontweight='bold', fontsize=10,
            ha='center', va='center', zorder=16)

ax.set_title(f'{team} Average Positions in Possession')

fig.savefig('my_visualised_tracking_data.png',dpi=300,format='png')

# %%
# Starters Onlyu

pitch = Pitch(pitch_type='skillcorner', line_alpha=0.75, pitch_length=105, pitch_width=68,
              pitch_color='#001400', line_color='white', linewidth=1.5)
fig, ax = pitch.grid(figheight=8, endnote_height=0, title_height=0)



# What to visualize
possession = 'IP' # or 'OOP'
team = aggregated_df.team_name.unique().tolist()[1] # Pick one team, you can use the name directly

viz_ip = aggregated_df[(aggregated_df['possession_flag'] == possession) & (aggregated_df['team_name'] == team) & (aggregated_df['start_time']=='00:00:00')].reset_index(drop=True)


ax.scatter(viz_ip['x'], viz_ip['y'],
               c='#32FE6B', alpha=0.95, s=600,
               edgecolors='white', linewidths=2.5, zorder=10,label='team')


# Annotate player numbers
for i, row in viz_ip.iterrows():
    ax.text(row['x'], row['y'], str(row['number']),
            color='black', fontweight='bold', fontsize=10,
            ha='center', va='center', zorder=16)

ax.set_title(f'{team} Average Positions in Possession')

fig.savefig('my_visualised_tracking_data_starters.png',dpi=300,format='png')
